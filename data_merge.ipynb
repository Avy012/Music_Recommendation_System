# %%
import pandas as pd

# %%
df = pd.read_csv('Music Info.csv')
user = pd.read_csv('User Listening History.csv')

# %%
merged = pd.merge(
    df,        # 왼쪽 테이블 (플레이리스트 트랙)
    user,        # 오른쪽 테이블 (메타 정보)
    on='track_id',
    how='inner',# 공통으로 존재하는 트랙만
    suffixes=('_pl', '_meta')
)
merged.reset_index(drop=True, inplace=True)
merged.drop_duplicates()
# Out:
#                    track_id               name       artist  \
# 0        TRIOREW128F424EAF0     Mr. Brightside  The Killers
# 1        TRIOREW128F424EAF0     Mr. Brightside  The Killers
# 2        TRIOREW128F424EAF0     Mr. Brightside  The Killers
# 3        TRIOREW128F424EAF0     Mr. Brightside  The Killers
# 4        TRIOREW128F424EAF0     Mr. Brightside  The Killers
# ...                     ...                ...          ...
# 9711296  TRGLMEM128F9322F63  Koi no Dependence  アンティック-珈琲店-
# 9711297  TRGLMEM128F9322F63  Koi no Dependence  アンティック-珈琲店-
# 9711298  TRGLMEM128F9322F63  Koi no Dependence  アンティック-珈琲店-
# 9711299  TRGLMEM128F9322F63  Koi no Dependence  アンティック-珈琲店-
# 9711300  TRGLMEM128F9322F63  Koi no Dependence  アンティック-珈琲店-
#
#                                        spotify_preview_url  \
# 0        https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# 1        https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# 2        https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# 3        https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# 4        https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# ...                                                    ...
# 9711296  https://p.scdn.co/mp3-preview/5a61e031df174666...
# 9711297  https://p.scdn.co/mp3-preview/5a61e031df174666...
# 9711298  https://p.scdn.co/mp3-preview/5a61e031df174666...
# 9711299  https://p.scdn.co/mp3-preview/5a61e031df174666...
# 9711300  https://p.scdn.co/mp3-preview/5a61e031df174666...
#
#                      spotify_id  \
# 0        09ZQ5TmUG8TSL56n0knqrj
# 1        09ZQ5TmUG8TSL56n0knqrj
# 2        09ZQ5TmUG8TSL56n0knqrj
# 3        09ZQ5TmUG8TSL56n0knqrj
# 4        09ZQ5TmUG8TSL56n0knqrj
# ...                         ...
# 9711296  1dxMDGvIYHFYgRvmw1uMHG
# 9711297  1dxMDGvIYHFYgRvmw1uMHG
# 9711298  1dxMDGvIYHFYgRvmw1uMHG
# 9711299  1dxMDGvIYHFYgRvmw1uMHG
# 9711300  1dxMDGvIYHFYgRvmw1uMHG
#
#                                                       tags genre  year  \
# 0        rock, alternative, indie, alternative_rock, in...   NaN  2004
# 1        rock, alternative, indie, alternative_rock, in...   NaN  2004
# 2        rock, alternative, indie, alternative_rock, in...   NaN  2004
# 3        rock, alternative, indie, alternative_rock, in...   NaN  2004
# 4        rock, alternative, indie, alternative_rock, in...   NaN  2004
# ...                                                    ...   ...   ...
# 9711296                                                NaN   NaN  2008
# 9711297                                                NaN   NaN  2008
# 9711298                                                NaN   NaN  2008
# 9711299                                                NaN   NaN  2008
# 9711300                                                NaN   NaN  2008
#
#          duration_ms  danceability  ...  mode  speechiness  acousticness  \
# 0             222200         0.355  ...     1       0.0746      0.001190
# 1             222200         0.355  ...     1       0.0746      0.001190
# 2             222200         0.355  ...     1       0.0746      0.001190
# 3             222200         0.355  ...     1       0.0746      0.001190
# 4             222200         0.355  ...     1       0.0746      0.001190
# ...              ...           ...  ...   ...          ...           ...
# 9711296       243293         0.513  ...     0       0.0530      0.000715
# 9711297       243293         0.513  ...     0       0.0530      0.000715
# 9711298       243293         0.513  ...     0       0.0530      0.000715
# 9711299       243293         0.513  ...     0       0.0530      0.000715
# 9711300       243293         0.513  ...     0       0.0530      0.000715
#
#          instrumentalness  liveness  valence    tempo  time_signature  \
# 0                 0.00000    0.0971    0.240  148.114               4
# 1                 0.00000    0.0971    0.240  148.114               4
# 2                 0.00000    0.0971    0.240  148.114               4
# 3                 0.00000    0.0971    0.240  148.114               4
# 4                 0.00000    0.0971    0.240  148.114               4
# ...                   ...       ...      ...      ...             ...
# 9711296           0.00135    0.0571    0.618  109.923               4
# 9711297           0.00135    0.0571    0.618  109.923               4
# 9711298           0.00135    0.0571    0.618  109.923               4
# 9711299           0.00135    0.0571    0.618  109.923               4
# 9711300           0.00135    0.0571    0.618  109.923               4
#
#                                           user_id  playcount
# 0        e95303796148a664af00f0e25059e38ab1823b30          1
# 1        d7a8dcae75b104184e9e243bd7d6f8c79567f286          1
# 2        c097ce6d176770f976b7fc98e8bcb0421b83c3b9          1
# 3        1c9fcbf32a26843605b2a0daf1beb42d52924903          1
# 4        37bb354237cf3a83cfe0d71d89b97a1d68e7d082          1
# ...                                           ...        ...
# 9711296  ffc90fd1e49268cf160d81772144fe7822e057e2          1
# 9711297  5a1dc54ef8d8dd2bd942e5fb5235b997375dc1d0          5
# 9711298  77af7914d6a13a9c67c5870e706c27c946869504          1
# 9711299  b72489e76b9789fe139b2f4998c6382a439018d5          1
# 9711300  76d3d1b7534ed0c6cdee7877deaae6deda38b9f7          6
#
# [9711301 rows x 23 columns]

# %%
extract = merged[['spotify_id','name','artist','user_id','playcount','duration_ms']]
users = extract.rename(columns={'spotify_id': 'track_uri'})
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9711301 entries, 0 to 9711300
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   track_uri    object
#  1   name         object
#  2   artist       object
#  3   user_id      object
#  4   playcount    int64
#  5   duration_ms  int64
# dtypes: int64(2), object(4)
# memory usage: 444.5+ MB

# %%
lyrics = pd.read_csv('songs_with_attributes_and_lyrics.csv')

# %%
lyrics.rename(columns={'id': 'track_uri'}, inplace=True)

merged2 = pd.merge(
    users,        # 왼쪽 테이블 (플레이리스트 트랙)
    lyrics,        # 오른쪽 테이블 (메타 정보)
    on='track_uri',
    how='inner',# 공통으로 존재하는 트랙만
    suffixes=('_pl', '_meta')
)
merged2.drop_duplicates().reset_index(drop=True, inplace=True)

# %%
merged2.rename(columns={'name_pl': 'track_name','duration_ms_pl':'duration_ms'}, inplace=True)
merged2.drop(['name_meta','album_name','artists','duration_ms_meta'], axis=1, inplace=True)
merged2
# Out:
#                       track_uri track_name                 artist  \
# 0        0BCPKOYdS2jbQ8iyB56Zns     Clocks               Coldplay
# 1        0BCPKOYdS2jbQ8iyB56Zns     Clocks               Coldplay
# 2        0BCPKOYdS2jbQ8iyB56Zns     Clocks               Coldplay
# 3        0BCPKOYdS2jbQ8iyB56Zns     Clocks               Coldplay
# 4        0BCPKOYdS2jbQ8iyB56Zns     Clocks               Coldplay
# ...                         ...        ...                    ...
# 1302613  5lQatPubYHgBIK22beDTi4    Keyword  9mm Parabellum Bullet
# 1302614  5lQatPubYHgBIK22beDTi4    Keyword  9mm Parabellum Bullet
# 1302615  5lQatPubYHgBIK22beDTi4    Keyword  9mm Parabellum Bullet
# 1302616  5lQatPubYHgBIK22beDTi4    Keyword  9mm Parabellum Bullet
# 1302617  5lQatPubYHgBIK22beDTi4    Keyword  9mm Parabellum Bullet
#
#                                           user_id  playcount  duration_ms  \
# 0        7241c0f8e15a4b9792ce5ddcfbe87a888f7f4b16          2       307879
# 1        8b5838c03d615893231d98995ff57d3f7a6659b9          4       307879
# 2        0fadffbb32e66100e27afc6a8a4a758ad8e9278b          1       307879
# 3        f3e946cfb7048b4c7a23240f4d8c94273f01f68a          1       307879
# 4        ba1defc039363ce394cc08a5a3fba7b86df7a2d6          1       307879
# ...                                           ...        ...          ...
# 1302613  85aa2a02ba31bf7d247f4b72585ac2a9cbeb97a5          2       203226
# 1302614  6364120099dfc1346e45123d3b90978eaa9fa419          1       203226
# 1302615  ae6817c823f0e9837d01660c04f9e6d061295055          1       203226
# 1302616  29676d2cc9920f9b44484824c7276eb0fbdbf4fd          5       203226
# 1302617  6b87163fff32a3dd4e065bf70845ad4cc829f573          1       203226
#
#          danceability  energy key  loudness mode  speechiness  acousticness  \
# 0               0.577   0.749   5    -7.215    0       0.0279      0.599000
# 1               0.577   0.749   5    -7.215    0       0.0279      0.599000
# 2               0.577   0.749   5    -7.215    0       0.0279      0.599000
# 3               0.577   0.749   5    -7.215    0       0.0279      0.599000
# 4               0.577   0.749   5    -7.215    0       0.0279      0.599000
# ...               ...     ...  ..       ...  ...          ...           ...
# 1302613         0.279   0.974   8    -3.481    1       0.1260      0.000811
# 1302614         0.279   0.974   8    -3.481    1       0.1260      0.000811
# 1302615         0.279   0.974   8    -3.481    1       0.1260      0.000811
# 1302616         0.279   0.974   8    -3.481    1       0.1260      0.000811
# 1302617         0.279   0.974   8    -3.481    1       0.1260      0.000811
#
#          instrumentalness  liveness  valence    tempo  \
# 0                0.011200    0.1830    0.261  130.969
# 1                0.011200    0.1830    0.261  130.969
# 2                0.011200    0.1830    0.261  130.969
# 3                0.011200    0.1830    0.261  130.969
# 4                0.011200    0.1830    0.261  130.969
# ...                   ...       ...      ...      ...
# 1302613          0.000041    0.0477    0.256  192.071
# 1302614          0.000041    0.0477    0.256  192.071
# 1302615          0.000041    0.0477    0.256  192.071
# 1302616          0.000041    0.0477    0.256  192.071
# 1302617          0.000041    0.0477    0.256  192.071
#
#                                                     lyrics
# 0        The lights go out, and I can't be saved\n Tide...
# 1        The lights go out, and I can't be saved\n Tide...
# 2        The lights go out, and I can't be saved\n Tide...
# 3        The lights go out, and I can't be saved\n Tide...
# 4        The lights go out, and I can't be saved\n Tide...
# ...                                                    ...
# 1302613  閉ざされたドアを開けるのは\n 取って付けられた合言葉\n 一度だけしか言わないから\n 愛...
# 1302614  閉ざされたドアを開けるのは\n 取って付けられた合言葉\n 一度だけしか言わないから\n 愛...
# 1302615  閉ざされたドアを開けるのは\n 取って付けられた合言葉\n 一度だけしか言わないから\n 愛...
# 1302616  閉ざされたドアを開けるのは\n 取って付けられた合言葉\n 一度だけしか言わないから\n 愛...
# 1302617  閉ざされたドアを開けるのは\n 取って付けられた合言葉\n 一度だけしか言わないから\n 愛...
#
# [1302618 rows x 18 columns]

# %%
# CSV로 저장
output_path = 'user_track.csv'
merged2.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"Saved to {output_path}")
# Out:
# Saved to user_track.csv
